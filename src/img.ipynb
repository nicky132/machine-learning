# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import cv2

# %%
cv2.__version__
# Out:
# '4.5.5'

# %%
img = cv2.imread('./resource/test.png')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img
# Out:
# array([[[164, 169, 168],
#         [161, 166, 165],
#         [159, 164, 163],
#         ...,
#         [180, 180, 180],
#         [182, 182, 182],
#         [182, 182, 182]],
#
#        [[164, 169, 168],
#         [162, 167, 166],
#         [159, 164, 163],
#         ...,
#         [180, 180, 180],
#         [182, 182, 182],
#         [182, 182, 182]],
#
#        [[165, 170, 169],
#         [162, 167, 166],
#         [159, 164, 163],
#         ...,
#         [180, 180, 180],
#         [182, 182, 182],
#         [182, 182, 182]],
#
#        ...,
#
#        [[ 44,  37,  34],
#         [ 45,  38,  35],
#         [ 36,  29,  26],
#         ...,
#         [ 99,  96,  95],
#         [ 67,  63,  62],
#         [ 34,  30,  29]],
#
#        [[ 40,  33,  30],
#         [ 50,  43,  40],
#         [ 45,  38,  35],
#         ...,
#         [ 48,  44,  43],
#         [ 33,  28,  27],
#         [ 42,  37,  36]],
#
#        [[ 44,  37,  34],
#         [ 38,  31,  28],
#         [ 45,  38,  35],
# ...

# %%
plt.imshow(img)

# %%
img_fixed = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

plt.imshow(img_fixed)

# %%
img_gray = cv2.imread('./resource/test.png',cv2.IMREAD_GRAYSCALE)

img_gray.shape
# Out:
# (1056, 1052)

# %%
plt.imshow(img_gray,cmap="gray")

# %%
img_resize = cv2.resize(img_fixed,(100,100))

plt.imshow(img_resize)

# %%
img_flip = cv2.flip(img_fixed,-1)
plt.imshow(img_flip)

# %%
img_save = cv2.cvtColor(img_fixed,cv2.COLOR_RGB2BGR)

cv2.imwrite('./resource/save.png',img_save)
# Out:
# True
